# %%
import os

os.chdir("..")

# %%
import yaml
from eng_id_nmt_basic.translate import translate, translate_beam_search

with open("config.yaml", "r") as f:
    config = yaml.safe_load(f)

model = config["paths"]["best_model_path"]

# %%
sentence = "We will go to the zoo"

translation = translate(model, sentence, max_length=100)
print(sentence)
print(f"= {translation}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
# We will go to the zoo
# = kita akan pergi ke [UNK]

# %%
sentence = "We will go to the zoo"

translation = translate_beam_search(model, sentence, max_length=100, beam_width=3)
print(sentence)
print(f"= {translation}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 751ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step
# We will go to the zoo
# = kita akan pergi ke [UNK]

# %%
sentence = "I do not like movies"

translation = translate(model, sentence, max_length=100)
print(sentence)
print(f"= {translation}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 890ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step
# I do not like movies
# = aku tidak suka film

# %%
sentence = "I do not like movies"

translation = translate_beam_search(model, sentence, max_length=100, beam_width=3)
print(sentence)
print(f"= {translation}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 987ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# I do not like movies
# = aku tidak suka film

# %%
sentence = "She is cooking some food"

translation = translate(model, sentence, max_length=100)
print(sentence)
print(f"= {translation}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step
# She is cooking some food
# = dia sedang bermain sepak bola
