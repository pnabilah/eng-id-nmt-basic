# %%
import os

os.chdir("..")

# %%
import yaml
from eng_id_nmt_basic.translate import translate

with open("config.yaml", "r") as f:
    config = yaml.safe_load(f)

model = config["paths"]["best_model_path"]

# %%
sentence = "We will go to the zoo"

translation = translate(model, sentence, max_length=100)
print(sentence)
print(f"= {translation}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 563ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step
# We will go to the zoo
# = kita akan pergi ke [UNK]
